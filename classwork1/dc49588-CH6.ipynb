# %% [markdown]
# ## Challenge 6a

# %%
import numpy as np
import time

A = np.array([[10,-1,2,0,0],
            [-1,11,-1,3,0],
            [2,-1,10,-1,0],
            [0,3,-1,8,-2],
            [0,0,0,-2,9]], dtype = float)
b = np.array([14,30,26,25,37], dtype = float)

#Jacobi
def jacobi(A,b,x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k+1
        x = x_new
    return x, max_iterations

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100000

t0 = time.perf_counter()
jacobi_solution, jacobi_iterations = jacobi(A, b, x0, tol, max_iterations)
t1 = time.perf_counter()

print(f"Jacobi Solution: {jacobi_solution}")
print(f"Iterations: {jacobi_iterations}")
print(f"Time: {t1 - t0}")

#Gauss-Seidel
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k + 1
        
        x = x_new
        
    return x, max_iterations

t2 = time.perf_counter()
gauss_solution, gauss_iterations = gauss_seidel(A, b, x0, tol, max_iterations)
t3 = time.perf_counter()
print(f"\nGauss-Seidel Solution: {gauss_solution}")
print(f"Iterations: {gauss_iterations}")
print(f"Time: {t3 - t2}")

#Compare convergence
#Gauss-Seidel converges in far less iterations
#Gauss-Seidel also takes less time to converge because of the fewer iterations
# Out:
# Jacobi Solution: [0.99999995 2.00000025 2.99999986 4.00000008 4.99999983]
# Iterations: 19
# Time: 0.0014178731944411993
#
# Gauss-Seidel Solution: [1.00000003 2.00000002 2.99999999 3.99999998 5.        ]
# Iterations: 11
# Time: 0.0007383399643003941

# %% [markdown]
# ## Challenge 6b

# %%
A = np.array([[1,2,3,0,0],
            [2,1,2,3,0],
            [3,2,1,2,3],
            [0,3,2,1,2],
            [0,0,3,2,1]], dtype = float)
b = np.array([14,22,33,26,22], dtype = float)

t0 = time.perf_counter()
jacobi_solution, jacobi_iterations = jacobi(A, b, x0, tol, max_iterations)
t1 = time.perf_counter()

print(f"Jacobi Solution: {jacobi_solution}")
print(f"Iterations: {jacobi_iterations}")
print(f"Time: {t1 - t0}")

t2 = time.perf_counter()
gauss_solution, gauss_iterations = gauss_seidel(A, b, x0, tol, max_iterations)
t3 = time.perf_counter()
print(f"\nGauss-Seidel Solution: {gauss_solution}")
print(f"Iterations: {gauss_iterations}")
print(f"Time: {t3 - t2}")

#Compare convergence:
#Neither method converges and I get a runtime error
#This is likely because they diverge
#These methods don't work because the matrix is not diagonally dominant
# Out:
# <ipython-input-27-7f3ebb72b1ad>:19: RuntimeWarning: overflow encountered in double_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-27-7f3ebb72b1ad>:19: RuntimeWarning: invalid value encountered in double_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# Jacobi Solution: [nan nan nan nan nan]
# Iterations: 100000
# Time: 4.40258880215697
# <ipython-input-27-7f3ebb72b1ad>:47: RuntimeWarning: overflow encountered in double_scalars
#   s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
# <ipython-input-27-7f3ebb72b1ad>:48: RuntimeWarning: overflow encountered in double_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
# <ipython-input-27-7f3ebb72b1ad>:48: RuntimeWarning: invalid value encountered in double_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
# Gauss-Seidel Solution: [nan nan nan nan nan]
# Iterations: 100000
# Time: 4.236810230184346
