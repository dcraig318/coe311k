# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.subplot(2,2,1)
plt.plot(x, x**2, 'r', label='X^2')
plt.legend()

plt.subplot(2,2,2)
plt.plot(x, np.cos(x), 'b', label='Cos(x)')
plt.legend()

plt.subplot(2,2,3)
plt.plot(x, np.tan(x), 'g', label='Tan(x)')
plt.legend()

plt.subplot(2,2,4)
x1 = np.random.rand(500)
y1 = np.random.rand(500)
size = np.random.rand(500) * 15
color = np.random.rand(500)

plt.scatter(X,Y, size, color, label='Scatter Plot')
plt.colorbar()
plt.legend()

plt.show()
